# %%
import os
import json

def parse_file(file_path):
    """Parse the content of a single file into a list of labels."""
    labels = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' ', 2)
            if len(parts) == 3:
                index, label, detail = parts
                labels.append(label)
    return labels

def parse_directory(directory):
    """Parse all files in the given directory and return a list of labels."""
    all_labels = []
    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)
        if os.path.isfile(file_path):
            file_labels = parse_file(file_path)
            all_labels.extend(file_labels)
    return all_labels

def assign_unique_indices(labels):
    """Create a dictionary with unique indices as keys and labels as values."""
    indexed_labels = {i: label for i, label in enumerate(labels, start=1)}
    return indexed_labels

def assign_unique_indices_reverse(labels):
    """Create a dictionary with unique indices as keys and labels as values."""
    indexed_labels = {label: i for i, label in enumerate(labels, start=1)}
    return indexed_labels

def save_to_json(data, output_file):
    """Save the dictionary to a JSON file."""
    with open(output_file, 'w') as file:
        json.dump(data, file, indent=4)

# Directory containing the text files
directory = 'partnet_dataset/stats/before_merging_label_ids'

# Parse the directory and get the labels
labels = parse_directory(directory)

# Assign unique indices to the labels
indexed_labels = assign_unique_indices(labels)

labels_indexed = assign_unique_indices_reverse(labels)
# Output file path
output_file = 'idx2label.json'
output_file_ = 'label2idx.json'

# Save the indexed labels to a JSON file
save_to_json(indexed_labels, output_file)
save_to_json(labels_indexed, output_file_)

print(f"Merged data written to {output_file}")

# The dictionary of parsed data with unique indices
indexed_labels_list = indexed_labels
# Out:
# Merged data written to idx2label.json

# %%
indexed_labels_list
# Out:
# {1: 'bottle',
#  2: 'bottle/normal_bottle',
#  3: 'bottle/normal_bottle/body',
#  4: 'bottle/normal_bottle/lid_handle',
#  5: 'bottle/normal_bottle/body_handle',
#  6: 'bottle/normal_bottle/neck',
#  7: 'bottle/normal_bottle/closure',
#  8: 'bottle/normal_bottle/lid',
#  9: 'bottle/normal_bottle/mouth',
#  10: 'bottle/normal_bottle/containing_things',
#  11: 'bottle/normal_bottle/containing_things/liquid',
#  12: 'bottle/jug',
#  13: 'bottle/jug/mouth',
#  14: 'bottle/jug/body',
#  15: 'bottle/jug/bottom',
#  16: 'bottle/jug/lid_handle',
#  17: 'bottle/jug/body_handle',
#  18: 'bottle/jug/lid',
#  19: 'bottle/jug/containing_things',
#  20: 'bottle/jug/containing_things/liquid',
#  21: 'chair',
#  22: 'chair/chair_head',
#  23: 'chair/chair_head/headrest',
#  24: 'chair/chair_head/head_connector',
#  25: 'chair/chair_head/pillow',
#  26: 'chair/chair_back',
#  27: 'chair/chair_back/back_surface',
#  28: 'chair/chair_back/back_surface/back_hard_surface',
#  29: 'chair/chair_back/back_surface/back_soft_surface',
#  30: 'chair/chair_back/back_surface/back_surface_vertical_bar',
#  31: 'chair/chair_back/back_surface/back_surface_horizontal_bar',
#  32: 'chair/chair_back/back_surface/back_surface_slant_bar',
#  33: 'chair/chair_back/back_surface/back_complex_decoration',
#  34: 'chair/chair_back/back_support',
#  35: 'chair/chair_back/back_frame',
#  36: 'chair/chair_back/back_frame/back_frame_vertical_bar',
#  37: 'chair/chair_back/back_frame/back_frame_horizontal_bar',
#  38: 'chair/chair_back/back_frame/back_frame_slant_bar',
#  39: 'chair/chair_back/back_frame/back_holistic_frame',
#  40: 'chair/chair_back/back_connector',
#  41: 'chair/chair_back/pillow',
#  42: 'chair/chair_arm',
#  43: 'chair/chair_arm/armrest_hard_surface',
#  44: 'chair/chair_arm/armrest_soft_surface',
#  45: 'chair/chair_arm/arm_horizontal_bar',
#  46: 'chair/chair_arm/arm_vertical_bar',
#  47: 'chair/chair_arm/arm_slant_bar',
#  48: 'chair/chair_arm/arm_holistic_frame',
#  49: 'chair/chair_arm/arm_sofa_style',
#  50: 'chair/chair_arm/arm_writing_table',
#  51: 'chair/chair_arm/arm_connector',
#  52: 'chair/chair_seat',
#  53: 'chair/chair_seat/seat_surface',
#  54: 'chair/chair_seat/seat_surface/seat_hard_surface',
#  55: 'chair/chair_seat/seat_surface/seat_soft_surface',
#  56: 'chair/chair_seat/seat_surface/seat_surface_vertical_bar',
#  57: 'chair/chair_seat/seat_surface/seat_surface_horizontal_bar',
#  58: 'chair/chair_seat/seat_surface/seat_surface_slant_bar',
#  59: 'chair/chair_seat/seat_support',
#  60: 'chair/chair_seat/seat_frame',
#  61: 'chair/chair_seat/seat_frame/seat_frame_vertical_bar',
#  62: 'chair/chair_seat/seat_frame/seat_frame_horizontal_bar',
#  63: 'chair/chair_seat/seat_frame/seat_frame_slant_bar',
#  64: 'chair/chair_seat/seat_frame/seat_holistic_frame',
#  65: 'chair/chair_seat/pillow',
#  66: 'chair/chair_base',
#  67: 'chair/chair_base/regular_leg_base',
#  68: 'chair/chair_base/regular_leg_base/leg',
#  69: 'chair/chair_base/regular_leg_base/foot',
#  70: 'chair/chair_base/regular_leg_base/caster',
#  71: 'chair/chair_base/regular_leg_base/caster/caster_yoke',
#  72: 'chair/chair_base/regular_leg_base/caster/caster_stem',
#  73: 'chair/chair_base/regular_leg_base/caster/caster_mounting_plate',
#  74: 'chair/chair_base/regular_leg_base/caster/wheel',
#  75: 'chair/chair_base/regular_leg_base/caster/brake',
#  76: 'chair/chair_base/regular_leg_base/bar_stretcher',
#  77: 'chair/chair_base/regular_leg_base/circular_stretcher',
#  78: 'chair/chair_base/regular_leg_base/runner',
#  79: 'chair/chair_base/regular_leg_base/rocker',
#  80: 'chair/chair_base/regular_leg_base/seat_connector',
#  81: 'chair/chair_base/star_leg_base',
#  82: 'chair/chair_base/star_leg_base/central_support',
#  83: 'chair/chair_base/star_leg_base/mechanical_control',
#  84: 'chair/chair_base/star_leg_base/mechanical_control/lever',
#  85: 'chair/chair_base/star_leg_base/mechanical_control/knob',
#  86: 'chair/chair_base/star_leg_base/mechanical_control/button',
#  87: 'chair/chair_base/star_leg_base/mechanical_control/mounting_plate',
#  88: 'chair/chair_base/star_leg_base/footrest_ring',
#  89: 'chair/chair_base/star_leg_base/footrest_ring/footrest_bar',
#  90: 'chair/chair_base/star_leg_base/footrest_ring/footrest_circular',
#  91: 'chair/chair_base/star_leg_base/star_leg_set',
#  92: 'chair/chair_base/star_leg_base/star_leg_set/leg',
#  93: 'chair/chair_base/star_leg_base/star_leg_set/foot',
#  94: 'chair/chair_base/star_leg_base/star_leg_set/caster',
#  95: 'chair/chair_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  96: 'chair/chair_base/star_leg_base/star_leg_set/caster/caster_stem',
#  97: 'chair/chair_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  98: 'chair/chair_base/star_leg_base/star_leg_set/caster/wheel',
#  99: 'chair/chair_base/star_leg_base/star_leg_set/caster/brake',
#  100: 'chair/chair_base/star_leg_base/seat_connector',
#  101: 'chair/chair_base/pedestal_base',
#  102: 'chair/chair_base/pedestal_base/central_support',
#  103: 'chair/chair_base/pedestal_base/mechanical_control',
#  104: 'chair/chair_base/pedestal_base/mechanical_control/lever',
#  105: 'chair/chair_base/pedestal_base/mechanical_control/knob',
#  106: 'chair/chair_base/pedestal_base/mechanical_control/button',
#  107: 'chair/chair_base/pedestal_base/mechanical_control/mounting_plate',
#  108: 'chair/chair_base/pedestal_base/footrest_ring',
#  109: 'chair/chair_base/pedestal_base/footrest_ring/footrest_bar',
#  110: 'chair/chair_base/pedestal_base/footrest_ring/footrest_circular',
#  111: 'chair/chair_base/pedestal_base/pedestal',
#  112: 'chair/chair_base/pedestal_base/seat_connector',
#  113: 'chair/chair_base/surface_base',
#  114: 'chair/chair_base/surface_base/ground_surface',
#  115: 'chair/chair_base/surface_base/side_surface',
#  116: 'chair/chair_base/surface_base/leg',
#  117: 'chair/chair_base/surface_base/foot',
#  118: 'chair/chair_base/surface_base/caster',
#  119: 'chair/chair_base/surface_base/caster/caster_yoke',
#  120: 'chair/chair_base/surface_base/caster/caster_stem',
#  121: 'chair/chair_base/surface_base/caster/caster_mounting_plate',
#  122: 'chair/chair_base/surface_base/caster/wheel',
#  123: 'chair/chair_base/surface_base/caster/brake',
#  124: 'chair/chair_base/surface_base/bar_stretcher',
#  125: 'chair/chair_base/surface_base/circular_stretcher',
#  126: 'chair/chair_base/surface_base/seat_connector',
#  127: 'chair/chair_base/foot_base',
#  128: 'chair/chair_base/foot_base/short_leg',
#  129: 'chair/chair_base/foot_base/foot',
#  130: 'chair/chair_base/foot_base/caster',
#  131: 'chair/chair_base/foot_base/caster/caster_yoke',
#  132: 'chair/chair_base/foot_base/caster/caster_stem',
#  133: 'chair/chair_base/foot_base/caster/caster_mounting_plate',
#  134: 'chair/chair_base/foot_base/caster/wheel',
#  135: 'chair/chair_base/foot_base/caster/brake',
#  136: 'chair/chair_base/foot_base/seat_connector',
#  137: 'chair/footrest',
#  138: 'chair/footrest/chair_seat',
#  139: 'chair/footrest/chair_seat/seat_surface',
#  140: 'chair/footrest/chair_seat/seat_surface/seat_hard_surface',
#  141: 'chair/footrest/chair_seat/seat_surface/seat_soft_surface',
#  142: 'chair/footrest/chair_seat/seat_surface/seat_surface_vertical_bar',
#  143: 'chair/footrest/chair_seat/seat_surface/seat_surface_horizontal_bar',
#  144: 'chair/footrest/chair_seat/seat_surface/seat_surface_slant_bar',
#  145: 'chair/footrest/chair_seat/seat_support',
#  146: 'chair/footrest/chair_seat/seat_frame',
#  147: 'chair/footrest/chair_seat/seat_frame/seat_frame_vertical_bar',
#  148: 'chair/footrest/chair_seat/seat_frame/seat_frame_horizontal_bar',
#  149: 'chair/footrest/chair_seat/seat_frame/seat_frame_slant_bar',
#  150: 'chair/footrest/chair_seat/seat_frame/seat_holistic_frame',
#  151: 'chair/footrest/chair_seat/pillow',
#  152: 'chair/footrest/chair_base',
#  153: 'chair/footrest/chair_base/regular_leg_base',
#  154: 'chair/footrest/chair_base/regular_leg_base/leg',
#  155: 'chair/footrest/chair_base/regular_leg_base/foot',
#  156: 'chair/footrest/chair_base/regular_leg_base/caster',
#  157: 'chair/footrest/chair_base/regular_leg_base/caster/caster_yoke',
#  158: 'chair/footrest/chair_base/regular_leg_base/caster/caster_stem',
#  159: 'chair/footrest/chair_base/regular_leg_base/caster/caster_mounting_plate',
#  160: 'chair/footrest/chair_base/regular_leg_base/caster/wheel',
#  161: 'chair/footrest/chair_base/regular_leg_base/caster/brake',
#  162: 'chair/footrest/chair_base/regular_leg_base/bar_stretcher',
#  163: 'chair/footrest/chair_base/regular_leg_base/circular_stretcher',
#  164: 'chair/footrest/chair_base/regular_leg_base/runner',
#  165: 'chair/footrest/chair_base/regular_leg_base/rocker',
#  166: 'chair/footrest/chair_base/regular_leg_base/seat_connector',
#  167: 'chair/footrest/chair_base/star_leg_base',
#  168: 'chair/footrest/chair_base/star_leg_base/central_support',
#  169: 'chair/footrest/chair_base/star_leg_base/mechanical_control',
#  170: 'chair/footrest/chair_base/star_leg_base/mechanical_control/lever',
#  171: 'chair/footrest/chair_base/star_leg_base/mechanical_control/knob',
#  172: 'chair/footrest/chair_base/star_leg_base/mechanical_control/button',
#  173: 'chair/footrest/chair_base/star_leg_base/mechanical_control/mounting_plate',
#  174: 'chair/footrest/chair_base/star_leg_base/footrest_ring',
#  175: 'chair/footrest/chair_base/star_leg_base/footrest_ring/footrest_bar',
#  176: 'chair/footrest/chair_base/star_leg_base/footrest_ring/footrest_circular',
#  177: 'chair/footrest/chair_base/star_leg_base/star_leg_set',
#  178: 'chair/footrest/chair_base/star_leg_base/star_leg_set/leg',
#  179: 'chair/footrest/chair_base/star_leg_base/star_leg_set/foot',
#  180: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster',
#  181: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  182: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster/caster_stem',
#  183: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  184: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster/wheel',
#  185: 'chair/footrest/chair_base/star_leg_base/star_leg_set/caster/brake',
#  186: 'chair/footrest/chair_base/star_leg_base/seat_connector',
#  187: 'chair/footrest/chair_base/pedestal_base',
#  188: 'chair/footrest/chair_base/pedestal_base/central_support',
#  189: 'chair/footrest/chair_base/pedestal_base/mechanical_control',
#  190: 'chair/footrest/chair_base/pedestal_base/mechanical_control/lever',
#  191: 'chair/footrest/chair_base/pedestal_base/mechanical_control/knob',
#  192: 'chair/footrest/chair_base/pedestal_base/mechanical_control/button',
#  193: 'chair/footrest/chair_base/pedestal_base/mechanical_control/mounting_plate',
#  194: 'chair/footrest/chair_base/pedestal_base/footrest_ring',
#  195: 'chair/footrest/chair_base/pedestal_base/footrest_ring/footrest_bar',
#  196: 'chair/footrest/chair_base/pedestal_base/footrest_ring/footrest_circular',
#  197: 'chair/footrest/chair_base/pedestal_base/pedestal',
#  198: 'chair/footrest/chair_base/pedestal_base/seat_connector',
#  199: 'chair/footrest/chair_base/surface_base',
#  200: 'chair/footrest/chair_base/surface_base/ground_surface',
#  201: 'chair/footrest/chair_base/surface_base/side_surface',
#  202: 'chair/footrest/chair_base/surface_base/leg',
#  203: 'chair/footrest/chair_base/surface_base/foot',
#  204: 'chair/footrest/chair_base/surface_base/caster',
#  205: 'chair/footrest/chair_base/surface_base/caster/caster_yoke',
#  206: 'chair/footrest/chair_base/surface_base/caster/caster_stem',
#  207: 'chair/footrest/chair_base/surface_base/caster/caster_mounting_plate',
#  208: 'chair/footrest/chair_base/surface_base/caster/wheel',
#  209: 'chair/footrest/chair_base/surface_base/caster/brake',
#  210: 'chair/footrest/chair_base/surface_base/bar_stretcher',
#  211: 'chair/footrest/chair_base/surface_base/circular_stretcher',
#  212: 'chair/footrest/chair_base/surface_base/seat_connector',
#  213: 'chair/footrest/chair_base/foot_base',
#  214: 'chair/footrest/chair_base/foot_base/short_leg',
#  215: 'chair/footrest/chair_base/foot_base/foot',
#  216: 'chair/footrest/chair_base/foot_base/caster',
#  217: 'chair/footrest/chair_base/foot_base/caster/caster_yoke',
#  218: 'chair/footrest/chair_base/foot_base/caster/caster_stem',
#  219: 'chair/footrest/chair_base/foot_base/caster/caster_mounting_plate',
#  220: 'chair/footrest/chair_base/foot_base/caster/wheel',
#  221: 'chair/footrest/chair_base/foot_base/caster/brake',
#  222: 'chair/footrest/chair_base/foot_base/seat_connector',
#  223: 'chair/footrest/footrest_connector',
#  224: 'display',
#  225: 'display/display_screen',
#  226: 'display/display_screen/frame',
#  227: 'display/display_screen/screen',
#  228: 'display/display_screen/button',
#  229: 'display/base',
#  230: 'display/base/surface_base',
#  231: 'display/base/surface_base/base_support',
#  232: 'display/base/surface_base/surface',
#  233: 'display/base/foot_base',
#  234: 'display/base/foot_base/foot',
#  235: 'display/accessories',
#  236: 'display/accessories/cord',
#  237: 'table',
#  238: 'table/regular_table',
#  239: 'table/regular_table/tabletop',
#  240: 'table/regular_table/tabletop/tabletop_surface',
#  241: 'table/regular_table/tabletop/tabletop_surface/bar',
#  242: 'table/regular_table/tabletop/tabletop_surface/board',
#  243: 'table/regular_table/tabletop/tabletop_surface/circle',
#  244: 'table/regular_table/tabletop/tabletop_surface/glass',
#  245: 'table/regular_table/tabletop/tabletop_frame',
#  246: 'table/regular_table/tabletop/tabletop_frame/bar',
#  247: 'table/regular_table/tabletop/tabletop_frame/board',
#  248: 'table/regular_table/tabletop/tabletop_frame/circle',
#  249: 'table/regular_table/tabletop/tabletop_dropleaf',
#  250: 'table/regular_table/tabletop/tabletop_dropleaf/bar',
#  251: 'table/regular_table/tabletop/tabletop_dropleaf/board',
#  252: 'table/regular_table/tabletop/tabletop_dropleaf/circle',
#  253: 'table/regular_table/tabletop/tabletop_dropleaf/glass',
#  254: 'table/regular_table/table_base',
#  255: 'table/regular_table/table_base/regular_leg_base',
#  256: 'table/regular_table/table_base/regular_leg_base/leg',
#  257: 'table/regular_table/table_base/regular_leg_base/foot',
#  258: 'table/regular_table/table_base/regular_leg_base/caster',
#  259: 'table/regular_table/table_base/regular_leg_base/caster/caster_yoke',
#  260: 'table/regular_table/table_base/regular_leg_base/caster/caster_stem',
#  261: 'table/regular_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  262: 'table/regular_table/table_base/regular_leg_base/caster/wheel',
#  263: 'table/regular_table/table_base/regular_leg_base/caster/brake',
#  264: 'table/regular_table/table_base/regular_leg_base/bar_stretcher',
#  265: 'table/regular_table/table_base/regular_leg_base/circular_stretcher',
#  266: 'table/regular_table/table_base/regular_leg_base/runner',
#  267: 'table/regular_table/table_base/regular_leg_base/tabletop_connector',
#  268: 'table/regular_table/table_base/star_leg_base',
#  269: 'table/regular_table/table_base/star_leg_base/central_support',
#  270: 'table/regular_table/table_base/star_leg_base/star_leg_set',
#  271: 'table/regular_table/table_base/star_leg_base/star_leg_set/leg',
#  272: 'table/regular_table/table_base/star_leg_base/star_leg_set/foot',
#  273: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster',
#  274: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  275: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  276: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  277: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  278: 'table/regular_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  279: 'table/regular_table/table_base/star_leg_base/tabletop_connector',
#  280: 'table/regular_table/table_base/pedestal_base',
#  281: 'table/regular_table/table_base/pedestal_base/central_support',
#  282: 'table/regular_table/table_base/pedestal_base/pedestal',
#  283: 'table/regular_table/table_base/pedestal_base/tabletop_connector',
#  284: 'table/regular_table/table_base/shelving_base',
#  285: 'table/regular_table/table_base/shelving_base/shelf',
#  286: 'table/regular_table/table_base/shelving_base/keyboard_tray',
#  287: 'table/regular_table/table_base/shelving_base/keyboard_tray/keyboard_tray_surface',
#  288: 'table/regular_table/table_base/shelving_base/keyboard_tray/keyboard_tray_rails',
#  289: 'table/regular_table/table_base/shelving_base/keyboard_tray/keyboard_tray_slider',
#  290: 'table/regular_table/table_base/shelving_base/back_panel',
#  291: 'table/regular_table/table_base/shelving_base/vertical_side_panel',
#  292: 'table/regular_table/table_base/shelving_base/vertical_front_panel',
#  293: 'table/regular_table/table_base/shelving_base/vertical_divider_panel',
#  294: 'table/regular_table/table_base/shelving_base/base_side_panel',
#  295: 'table/regular_table/table_base/shelving_base/bottom_panel',
#  296: 'table/regular_table/table_base/shelving_base/leg',
#  297: 'table/regular_table/table_base/shelving_base/foot',
#  298: 'table/regular_table/table_base/shelving_base/caster',
#  299: 'table/regular_table/table_base/shelving_base/caster/caster_yoke',
#  300: 'table/regular_table/table_base/shelving_base/caster/caster_stem',
#  301: 'table/regular_table/table_base/shelving_base/caster/caster_mounting_plate',
#  302: 'table/regular_table/table_base/shelving_base/caster/wheel',
#  303: 'table/regular_table/table_base/shelving_base/caster/brake',
#  304: 'table/regular_table/table_base/shelving_base/runner',
#  305: 'table/regular_table/table_base/shelving_base/bar_stretcher',
#  306: 'table/regular_table/table_base/shelving_base/circular_stretcher',
#  307: 'table/regular_table/table_base/shelving_base/tabletop_connector',
#  308: 'table/regular_table/table_base/drawer_base',
#  309: 'table/regular_table/table_base/drawer_base/drawer',
#  310: 'table/regular_table/table_base/drawer_base/drawer/drawer_box',
#  311: 'table/regular_table/table_base/drawer_base/drawer/drawer_box/drawer_front',
#  312: 'table/regular_table/table_base/drawer_base/drawer/drawer_box/drawer_side',
#  313: 'table/regular_table/table_base/drawer_base/drawer/drawer_box/drawer_back',
#  314: 'table/regular_table/table_base/drawer_base/drawer/drawer_box/drawer_bottom',
#  315: 'table/regular_table/table_base/drawer_base/drawer/handle',
#  316: 'table/regular_table/table_base/drawer_base/drawer/drawer_rails',
#  317: 'table/regular_table/table_base/drawer_base/drawer/drawer_slider',
#  318: 'table/regular_table/table_base/drawer_base/cabinet_door',
#  319: 'table/regular_table/table_base/drawer_base/cabinet_door/cabinet_door_surface',
#  320: 'table/regular_table/table_base/drawer_base/cabinet_door/handle',
#  321: 'table/regular_table/table_base/drawer_base/cabinet_door/hinge',
#  322: 'table/regular_table/table_base/drawer_base/cabinet_door/glass',
#  323: 'table/regular_table/table_base/drawer_base/shelf',
#  324: 'table/regular_table/table_base/drawer_base/keyboard_tray',
#  325: 'table/regular_table/table_base/drawer_base/keyboard_tray/keyboard_tray_surface',
#  326: 'table/regular_table/table_base/drawer_base/keyboard_tray/keyboard_tray_rails',
#  327: 'table/regular_table/table_base/drawer_base/keyboard_tray/keyboard_tray_slider',
#  328: 'table/regular_table/table_base/drawer_base/back_panel',
#  329: 'table/regular_table/table_base/drawer_base/vertical_side_panel',
#  330: 'table/regular_table/table_base/drawer_base/vertical_front_panel',
#  331: 'table/regular_table/table_base/drawer_base/vertical_divider_panel',
#  332: 'table/regular_table/table_base/drawer_base/base_side_panel',
#  333: 'table/regular_table/table_base/drawer_base/bottom_panel',
#  334: 'table/regular_table/table_base/drawer_base/leg',
#  335: 'table/regular_table/table_base/drawer_base/foot',
#  336: 'table/regular_table/table_base/drawer_base/caster',
#  337: 'table/regular_table/table_base/drawer_base/caster/caster_yoke',
#  338: 'table/regular_table/table_base/drawer_base/caster/caster_stem',
#  339: 'table/regular_table/table_base/drawer_base/caster/caster_mounting_plate',
#  340: 'table/regular_table/table_base/drawer_base/caster/wheel',
#  341: 'table/regular_table/table_base/drawer_base/caster/brake',
#  342: 'table/regular_table/table_base/drawer_base/runner',
#  343: 'table/regular_table/table_base/drawer_base/bar_stretcher',
#  344: 'table/regular_table/table_base/drawer_base/circular_stretcher',
#  345: 'table/regular_table/table_base/drawer_base/tabletop_connector',
#  346: 'table/regular_table/table_base/irregular_base',
#  347: 'table/regular_table/table_base/irregular_base/leg',
#  348: 'table/regular_table/table_base/irregular_base/foot',
#  349: 'table/regular_table/table_base/irregular_base/caster',
#  350: 'table/regular_table/table_base/irregular_base/caster/caster_yoke',
#  351: 'table/regular_table/table_base/irregular_base/caster/caster_stem',
#  352: 'table/regular_table/table_base/irregular_base/caster/caster_mounting_plate',
#  353: 'table/regular_table/table_base/irregular_base/caster/wheel',
#  354: 'table/regular_table/table_base/irregular_base/caster/brake',
#  355: 'table/regular_table/table_base/irregular_base/shelf',
#  356: 'table/regular_table/table_base/irregular_base/bar_stretcher',
#  357: 'table/regular_table/table_base/irregular_base/circular_stretcher',
#  358: 'table/regular_table/table_base/irregular_base/runner',
#  359: 'table/regular_table/table_base/irregular_base/tabletop_connector',
#  360: 'table/regular_table/object',
#  361: 'table/regular_table/object/book',
#  362: 'table/regular_table/object/television',
#  363: 'table/regular_table/object/clothes',
#  364: 'table/regular_table/object/shoes',
#  365: 'table/regular_table/object/vase',
#  366: 'table/regular_table/object/picture_frame',
#  367: 'table/desk',
#  368: 'table/desk/tabletop',
#  369: 'table/desk/tabletop/tabletop_surface',
#  370: 'table/desk/tabletop/tabletop_surface/bar',
#  371: 'table/desk/tabletop/tabletop_surface/board',
#  372: 'table/desk/tabletop/tabletop_surface/circle',
#  373: 'table/desk/tabletop/tabletop_surface/glass',
#  374: 'table/desk/tabletop/tabletop_frame',
#  375: 'table/desk/tabletop/tabletop_frame/bar',
#  376: 'table/desk/tabletop/tabletop_frame/board',
#  377: 'table/desk/tabletop/tabletop_frame/circle',
#  378: 'table/desk/tabletop/tabletop_dropleaf',
#  379: 'table/desk/tabletop/tabletop_dropleaf/bar',
#  380: 'table/desk/tabletop/tabletop_dropleaf/board',
#  381: 'table/desk/tabletop/tabletop_dropleaf/circle',
#  382: 'table/desk/tabletop/tabletop_dropleaf/glass',
#  383: 'table/desk/drawer_base',
#  384: 'table/desk/drawer_base/drawer',
#  385: 'table/desk/drawer_base/drawer/drawer_box',
#  386: 'table/desk/drawer_base/drawer/drawer_box/drawer_front',
#  387: 'table/desk/drawer_base/drawer/drawer_box/drawer_side',
#  388: 'table/desk/drawer_base/drawer/drawer_box/drawer_back',
#  389: 'table/desk/drawer_base/drawer/drawer_box/drawer_bottom',
#  390: 'table/desk/drawer_base/drawer/handle',
#  391: 'table/desk/drawer_base/drawer/drawer_rails',
#  392: 'table/desk/drawer_base/drawer/drawer_slider',
#  393: 'table/desk/drawer_base/cabinet_door',
#  394: 'table/desk/drawer_base/cabinet_door/cabinet_door_surface',
#  395: 'table/desk/drawer_base/cabinet_door/handle',
#  396: 'table/desk/drawer_base/cabinet_door/hinge',
#  397: 'table/desk/drawer_base/cabinet_door/glass',
#  398: 'table/desk/drawer_base/shelf',
#  399: 'table/desk/drawer_base/keyboard_tray',
#  400: 'table/desk/drawer_base/keyboard_tray/keyboard_tray_surface',
#  401: 'table/desk/drawer_base/keyboard_tray/keyboard_tray_rails',
#  402: 'table/desk/drawer_base/keyboard_tray/keyboard_tray_slider',
#  403: 'table/desk/drawer_base/back_panel',
#  404: 'table/desk/drawer_base/vertical_side_panel',
#  405: 'table/desk/drawer_base/vertical_front_panel',
#  406: 'table/desk/drawer_base/vertical_divider_panel',
#  407: 'table/desk/drawer_base/base_side_panel',
#  408: 'table/desk/drawer_base/bottom_panel',
#  409: 'table/desk/drawer_base/leg',
#  410: 'table/desk/drawer_base/foot',
#  411: 'table/desk/drawer_base/caster',
#  412: 'table/desk/drawer_base/caster/caster_yoke',
#  413: 'table/desk/drawer_base/caster/caster_stem',
#  414: 'table/desk/drawer_base/caster/caster_mounting_plate',
#  415: 'table/desk/drawer_base/caster/wheel',
#  416: 'table/desk/drawer_base/caster/brake',
#  417: 'table/desk/drawer_base/runner',
#  418: 'table/desk/drawer_base/bar_stretcher',
#  419: 'table/desk/drawer_base/circular_stretcher',
#  420: 'table/desk/drawer_base/tabletop_connector',
#  421: 'table/desk/hutch',
#  422: 'table/desk/hutch/shelf',
#  423: 'table/desk/hutch/back_panel',
#  424: 'table/desk/hutch/vertical_divider_panel',
#  425: 'table/desk/hutch/vertical_side_panel',
#  426: 'table/desk/hutch/vertical_front_panel',
#  427: 'table/desk/hutch/top_panel',
#  428: 'table/desk/hutch/cabinet_door',
#  429: 'table/desk/hutch/cabinet_door/cabinet_door_surface',
#  430: 'table/desk/hutch/cabinet_door/handle',
#  431: 'table/desk/hutch/cabinet_door/hinge',
#  432: 'table/desk/hutch/cabinet_door/glass',
#  433: 'table/desk/hutch/drawer',
#  434: 'table/desk/hutch/drawer/drawer_box',
#  435: 'table/desk/hutch/drawer/drawer_box/drawer_front',
#  436: 'table/desk/hutch/drawer/drawer_box/drawer_side',
#  437: 'table/desk/hutch/drawer/drawer_box/drawer_back',
#  438: 'table/desk/hutch/drawer/drawer_box/drawer_bottom',
#  439: 'table/desk/hutch/drawer/handle',
#  440: 'table/desk/hutch/drawer/drawer_rails',
#  441: 'table/desk/hutch/drawer/drawer_slider',
#  442: 'table/desk/object',
#  443: 'table/desk/object/book',
#  444: 'table/desk/object/television',
#  445: 'table/desk/object/clothes',
#  446: 'table/desk/object/shoes',
#  447: 'table/desk/object/vase',
#  448: 'table/desk/object/picture_frame',
#  449: 'table/game_table',
#  450: 'table/game_table/pool_table',
#  451: 'table/game_table/pool_table/tabletop',
#  452: 'table/game_table/pool_table/tabletop/tabletop_surface',
#  453: 'table/game_table/pool_table/tabletop/tabletop_surface/bar',
#  454: 'table/game_table/pool_table/tabletop/tabletop_surface/board',
#  455: 'table/game_table/pool_table/tabletop/tabletop_surface/circle',
#  456: 'table/game_table/pool_table/tabletop/tabletop_surface/glass',
#  457: 'table/game_table/pool_table/tabletop/tabletop_frame',
#  458: 'table/game_table/pool_table/tabletop/tabletop_frame/bar',
#  459: 'table/game_table/pool_table/tabletop/tabletop_frame/board',
#  460: 'table/game_table/pool_table/tabletop/tabletop_frame/circle',
#  461: 'table/game_table/pool_table/tabletop/tabletop_dropleaf',
#  462: 'table/game_table/pool_table/tabletop/tabletop_dropleaf/bar',
#  463: 'table/game_table/pool_table/tabletop/tabletop_dropleaf/board',
#  464: 'table/game_table/pool_table/tabletop/tabletop_dropleaf/circle',
#  465: 'table/game_table/pool_table/tabletop/tabletop_dropleaf/glass',
#  466: 'table/game_table/pool_table/table_base',
#  467: 'table/game_table/pool_table/table_base/regular_leg_base',
#  468: 'table/game_table/pool_table/table_base/regular_leg_base/leg',
#  469: 'table/game_table/pool_table/table_base/regular_leg_base/foot',
#  470: 'table/game_table/pool_table/table_base/regular_leg_base/caster',
#  471: 'table/game_table/pool_table/table_base/regular_leg_base/caster/caster_yoke',
#  472: 'table/game_table/pool_table/table_base/regular_leg_base/caster/caster_stem',
#  473: 'table/game_table/pool_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  474: 'table/game_table/pool_table/table_base/regular_leg_base/caster/wheel',
#  475: 'table/game_table/pool_table/table_base/regular_leg_base/caster/brake',
#  476: 'table/game_table/pool_table/table_base/regular_leg_base/bar_stretcher',
#  477: 'table/game_table/pool_table/table_base/regular_leg_base/circular_stretcher',
#  478: 'table/game_table/pool_table/table_base/regular_leg_base/runner',
#  479: 'table/game_table/pool_table/table_base/regular_leg_base/tabletop_connector',
#  480: 'table/game_table/pool_table/table_base/star_leg_base',
#  481: 'table/game_table/pool_table/table_base/star_leg_base/central_support',
#  482: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set',
#  483: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/leg',
#  484: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/foot',
#  485: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster',
#  486: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  487: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  488: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  489: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  490: 'table/game_table/pool_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  491: 'table/game_table/pool_table/table_base/star_leg_base/tabletop_connector',
#  492: 'table/game_table/pool_table/table_base/pedestal_base',
#  493: 'table/game_table/pool_table/table_base/pedestal_base/central_support',
#  494: 'table/game_table/pool_table/table_base/pedestal_base/pedestal',
#  495: 'table/game_table/pool_table/table_base/pedestal_base/tabletop_connector',
#  496: 'table/game_table/pool_table/table_base/shelving_base',
#  497: 'table/game_table/pool_table/table_base/shelving_base/shelf',
#  498: 'table/game_table/pool_table/table_base/shelving_base/keyboard_tray',
#  499: 'table/game_table/pool_table/table_base/shelving_base/keyboard_tray/keyboard_tray_surface',
#  500: 'table/game_table/pool_table/table_base/shelving_base/keyboard_tray/keyboard_tray_rails',
#  501: 'table/game_table/pool_table/table_base/shelving_base/keyboard_tray/keyboard_tray_slider',
#  502: 'table/game_table/pool_table/table_base/shelving_base/back_panel',
#  503: 'table/game_table/pool_table/table_base/shelving_base/vertical_side_panel',
#  504: 'table/game_table/pool_table/table_base/shelving_base/vertical_front_panel',
#  505: 'table/game_table/pool_table/table_base/shelving_base/vertical_divider_panel',
#  506: 'table/game_table/pool_table/table_base/shelving_base/base_side_panel',
#  507: 'table/game_table/pool_table/table_base/shelving_base/bottom_panel',
#  508: 'table/game_table/pool_table/table_base/shelving_base/leg',
#  509: 'table/game_table/pool_table/table_base/shelving_base/foot',
#  510: 'table/game_table/pool_table/table_base/shelving_base/caster',
#  511: 'table/game_table/pool_table/table_base/shelving_base/caster/caster_yoke',
#  512: 'table/game_table/pool_table/table_base/shelving_base/caster/caster_stem',
#  513: 'table/game_table/pool_table/table_base/shelving_base/caster/caster_mounting_plate',
#  514: 'table/game_table/pool_table/table_base/shelving_base/caster/wheel',
#  515: 'table/game_table/pool_table/table_base/shelving_base/caster/brake',
#  516: 'table/game_table/pool_table/table_base/shelving_base/runner',
#  517: 'table/game_table/pool_table/table_base/shelving_base/bar_stretcher',
#  518: 'table/game_table/pool_table/table_base/shelving_base/circular_stretcher',
#  519: 'table/game_table/pool_table/table_base/shelving_base/tabletop_connector',
#  520: 'table/game_table/pool_table/table_base/drawer_base',
#  521: 'table/game_table/pool_table/table_base/drawer_base/drawer',
#  522: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_box',
#  523: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_box/drawer_front',
#  524: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_box/drawer_side',
#  525: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_box/drawer_back',
#  526: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_box/drawer_bottom',
#  527: 'table/game_table/pool_table/table_base/drawer_base/drawer/handle',
#  528: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_rails',
#  529: 'table/game_table/pool_table/table_base/drawer_base/drawer/drawer_slider',
#  530: 'table/game_table/pool_table/table_base/drawer_base/cabinet_door',
#  531: 'table/game_table/pool_table/table_base/drawer_base/cabinet_door/cabinet_door_surface',
#  532: 'table/game_table/pool_table/table_base/drawer_base/cabinet_door/handle',
#  533: 'table/game_table/pool_table/table_base/drawer_base/cabinet_door/hinge',
#  534: 'table/game_table/pool_table/table_base/drawer_base/cabinet_door/glass',
#  535: 'table/game_table/pool_table/table_base/drawer_base/shelf',
#  536: 'table/game_table/pool_table/table_base/drawer_base/keyboard_tray',
#  537: 'table/game_table/pool_table/table_base/drawer_base/keyboard_tray/keyboard_tray_surface',
#  538: 'table/game_table/pool_table/table_base/drawer_base/keyboard_tray/keyboard_tray_rails',
#  539: 'table/game_table/pool_table/table_base/drawer_base/keyboard_tray/keyboard_tray_slider',
#  540: 'table/game_table/pool_table/table_base/drawer_base/back_panel',
#  541: 'table/game_table/pool_table/table_base/drawer_base/vertical_side_panel',
#  542: 'table/game_table/pool_table/table_base/drawer_base/vertical_front_panel',
#  543: 'table/game_table/pool_table/table_base/drawer_base/vertical_divider_panel',
#  544: 'table/game_table/pool_table/table_base/drawer_base/base_side_panel',
#  545: 'table/game_table/pool_table/table_base/drawer_base/bottom_panel',
#  546: 'table/game_table/pool_table/table_base/drawer_base/leg',
#  547: 'table/game_table/pool_table/table_base/drawer_base/foot',
#  548: 'table/game_table/pool_table/table_base/drawer_base/caster',
#  549: 'table/game_table/pool_table/table_base/drawer_base/caster/caster_yoke',
#  550: 'table/game_table/pool_table/table_base/drawer_base/caster/caster_stem',
#  551: 'table/game_table/pool_table/table_base/drawer_base/caster/caster_mounting_plate',
#  552: 'table/game_table/pool_table/table_base/drawer_base/caster/wheel',
#  553: 'table/game_table/pool_table/table_base/drawer_base/caster/brake',
#  554: 'table/game_table/pool_table/table_base/drawer_base/runner',
#  555: 'table/game_table/pool_table/table_base/drawer_base/bar_stretcher',
#  556: 'table/game_table/pool_table/table_base/drawer_base/circular_stretcher',
#  557: 'table/game_table/pool_table/table_base/drawer_base/tabletop_connector',
#  558: 'table/game_table/pool_table/table_base/irregular_base',
#  559: 'table/game_table/pool_table/table_base/irregular_base/leg',
#  560: 'table/game_table/pool_table/table_base/irregular_base/foot',
#  561: 'table/game_table/pool_table/table_base/irregular_base/caster',
#  562: 'table/game_table/pool_table/table_base/irregular_base/caster/caster_yoke',
#  563: 'table/game_table/pool_table/table_base/irregular_base/caster/caster_stem',
#  564: 'table/game_table/pool_table/table_base/irregular_base/caster/caster_mounting_plate',
#  565: 'table/game_table/pool_table/table_base/irregular_base/caster/wheel',
#  566: 'table/game_table/pool_table/table_base/irregular_base/caster/brake',
#  567: 'table/game_table/pool_table/table_base/irregular_base/shelf',
#  568: 'table/game_table/pool_table/table_base/irregular_base/bar_stretcher',
#  569: 'table/game_table/pool_table/table_base/irregular_base/circular_stretcher',
#  570: 'table/game_table/pool_table/table_base/irregular_base/runner',
#  571: 'table/game_table/pool_table/table_base/irregular_base/tabletop_connector',
#  572: 'table/game_table/pool_table/pool_cue_stick',
#  573: 'table/game_table/pool_table/pool_ball',
#  574: 'table/game_table/pool_table/pool_ball_rack',
#  575: 'table/game_table/ping_pong_table',
#  576: 'table/game_table/ping_pong_table/tabletop',
#  577: 'table/game_table/ping_pong_table/tabletop/tabletop_surface',
#  578: 'table/game_table/ping_pong_table/tabletop/tabletop_surface/bar',
#  579: 'table/game_table/ping_pong_table/tabletop/tabletop_surface/board',
#  580: 'table/game_table/ping_pong_table/tabletop/tabletop_surface/circle',
#  581: 'table/game_table/ping_pong_table/tabletop/tabletop_surface/glass',
#  582: 'table/game_table/ping_pong_table/tabletop/tabletop_frame',
#  583: 'table/game_table/ping_pong_table/tabletop/tabletop_frame/bar',
#  584: 'table/game_table/ping_pong_table/tabletop/tabletop_frame/board',
#  585: 'table/game_table/ping_pong_table/tabletop/tabletop_frame/circle',
#  586: 'table/game_table/ping_pong_table/tabletop/tabletop_dropleaf',
#  587: 'table/game_table/ping_pong_table/tabletop/tabletop_dropleaf/bar',
#  588: 'table/game_table/ping_pong_table/tabletop/tabletop_dropleaf/board',
#  589: 'table/game_table/ping_pong_table/tabletop/tabletop_dropleaf/circle',
#  590: 'table/game_table/ping_pong_table/tabletop/tabletop_dropleaf/glass',
#  591: 'table/game_table/ping_pong_table/table_base',
#  592: 'table/game_table/ping_pong_table/table_base/regular_leg_base',
#  593: 'table/game_table/ping_pong_table/table_base/regular_leg_base/leg',
#  594: 'table/game_table/ping_pong_table/table_base/regular_leg_base/foot',
#  595: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster',
#  596: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster/caster_yoke',
#  597: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster/caster_stem',
#  598: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  599: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster/wheel',
#  600: 'table/game_table/ping_pong_table/table_base/regular_leg_base/caster/brake',
#  601: 'table/game_table/ping_pong_table/table_base/regular_leg_base/bar_stretcher',
#  602: 'table/game_table/ping_pong_table/table_base/regular_leg_base/circular_stretcher',
#  603: 'table/game_table/ping_pong_table/table_base/regular_leg_base/runner',
#  604: 'table/game_table/ping_pong_table/table_base/regular_leg_base/tabletop_connector',
#  605: 'table/game_table/ping_pong_table/table_base/star_leg_base',
#  606: 'table/game_table/ping_pong_table/table_base/star_leg_base/central_support',
#  607: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set',
#  608: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/leg',
#  609: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/foot',
#  610: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster',
#  611: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  612: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  613: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  614: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  615: 'table/game_table/ping_pong_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  616: 'table/game_table/ping_pong_table/table_base/star_leg_base/tabletop_connector',
#  617: 'table/game_table/ping_pong_table/table_base/pedestal_base',
#  618: 'table/game_table/ping_pong_table/table_base/pedestal_base/central_support',
#  619: 'table/game_table/ping_pong_table/table_base/pedestal_base/pedestal',
#  620: 'table/game_table/ping_pong_table/table_base/pedestal_base/tabletop_connector',
#  621: 'table/game_table/ping_pong_table/table_base/shelving_base',
#  622: 'table/game_table/ping_pong_table/table_base/shelving_base/shelf',
#  623: 'table/game_table/ping_pong_table/table_base/shelving_base/keyboard_tray',
#  624: 'table/game_table/ping_pong_table/table_base/shelving_base/keyboard_tray/keyboard_tray_surface',
#  625: 'table/game_table/ping_pong_table/table_base/shelving_base/keyboard_tray/keyboard_tray_rails',
#  626: 'table/game_table/ping_pong_table/table_base/shelving_base/keyboard_tray/keyboard_tray_slider',
#  627: 'table/game_table/ping_pong_table/table_base/shelving_base/back_panel',
#  628: 'table/game_table/ping_pong_table/table_base/shelving_base/vertical_side_panel',
#  629: 'table/game_table/ping_pong_table/table_base/shelving_base/vertical_front_panel',
#  630: 'table/game_table/ping_pong_table/table_base/shelving_base/vertical_divider_panel',
#  631: 'table/game_table/ping_pong_table/table_base/shelving_base/base_side_panel',
#  632: 'table/game_table/ping_pong_table/table_base/shelving_base/bottom_panel',
#  633: 'table/game_table/ping_pong_table/table_base/shelving_base/leg',
#  634: 'table/game_table/ping_pong_table/table_base/shelving_base/foot',
#  635: 'table/game_table/ping_pong_table/table_base/shelving_base/caster',
#  636: 'table/game_table/ping_pong_table/table_base/shelving_base/caster/caster_yoke',
#  637: 'table/game_table/ping_pong_table/table_base/shelving_base/caster/caster_stem',
#  638: 'table/game_table/ping_pong_table/table_base/shelving_base/caster/caster_mounting_plate',
#  639: 'table/game_table/ping_pong_table/table_base/shelving_base/caster/wheel',
#  640: 'table/game_table/ping_pong_table/table_base/shelving_base/caster/brake',
#  641: 'table/game_table/ping_pong_table/table_base/shelving_base/runner',
#  642: 'table/game_table/ping_pong_table/table_base/shelving_base/bar_stretcher',
#  643: 'table/game_table/ping_pong_table/table_base/shelving_base/circular_stretcher',
#  644: 'table/game_table/ping_pong_table/table_base/shelving_base/tabletop_connector',
#  645: 'table/game_table/ping_pong_table/table_base/drawer_base',
#  646: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer',
#  647: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_box',
#  648: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_box/drawer_front',
#  649: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_box/drawer_side',
#  650: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_box/drawer_back',
#  651: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_box/drawer_bottom',
#  652: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/handle',
#  653: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_rails',
#  654: 'table/game_table/ping_pong_table/table_base/drawer_base/drawer/drawer_slider',
#  655: 'table/game_table/ping_pong_table/table_base/drawer_base/cabinet_door',
#  656: 'table/game_table/ping_pong_table/table_base/drawer_base/cabinet_door/cabinet_door_surface',
#  657: 'table/game_table/ping_pong_table/table_base/drawer_base/cabinet_door/handle',
#  658: 'table/game_table/ping_pong_table/table_base/drawer_base/cabinet_door/hinge',
#  659: 'table/game_table/ping_pong_table/table_base/drawer_base/cabinet_door/glass',
#  660: 'table/game_table/ping_pong_table/table_base/drawer_base/shelf',
#  661: 'table/game_table/ping_pong_table/table_base/drawer_base/keyboard_tray',
#  662: 'table/game_table/ping_pong_table/table_base/drawer_base/keyboard_tray/keyboard_tray_surface',
#  663: 'table/game_table/ping_pong_table/table_base/drawer_base/keyboard_tray/keyboard_tray_rails',
#  664: 'table/game_table/ping_pong_table/table_base/drawer_base/keyboard_tray/keyboard_tray_slider',
#  665: 'table/game_table/ping_pong_table/table_base/drawer_base/back_panel',
#  666: 'table/game_table/ping_pong_table/table_base/drawer_base/vertical_side_panel',
#  667: 'table/game_table/ping_pong_table/table_base/drawer_base/vertical_front_panel',
#  668: 'table/game_table/ping_pong_table/table_base/drawer_base/vertical_divider_panel',
#  669: 'table/game_table/ping_pong_table/table_base/drawer_base/base_side_panel',
#  670: 'table/game_table/ping_pong_table/table_base/drawer_base/bottom_panel',
#  671: 'table/game_table/ping_pong_table/table_base/drawer_base/leg',
#  672: 'table/game_table/ping_pong_table/table_base/drawer_base/foot',
#  673: 'table/game_table/ping_pong_table/table_base/drawer_base/caster',
#  674: 'table/game_table/ping_pong_table/table_base/drawer_base/caster/caster_yoke',
#  675: 'table/game_table/ping_pong_table/table_base/drawer_base/caster/caster_stem',
#  676: 'table/game_table/ping_pong_table/table_base/drawer_base/caster/caster_mounting_plate',
#  677: 'table/game_table/ping_pong_table/table_base/drawer_base/caster/wheel',
#  678: 'table/game_table/ping_pong_table/table_base/drawer_base/caster/brake',
#  679: 'table/game_table/ping_pong_table/table_base/drawer_base/runner',
#  680: 'table/game_table/ping_pong_table/table_base/drawer_base/bar_stretcher',
#  681: 'table/game_table/ping_pong_table/table_base/drawer_base/circular_stretcher',
#  682: 'table/game_table/ping_pong_table/table_base/drawer_base/tabletop_connector',
#  683: 'table/game_table/ping_pong_table/table_base/irregular_base',
#  684: 'table/game_table/ping_pong_table/table_base/irregular_base/leg',
#  685: 'table/game_table/ping_pong_table/table_base/irregular_base/foot',
#  686: 'table/game_table/ping_pong_table/table_base/irregular_base/caster',
#  687: 'table/game_table/ping_pong_table/table_base/irregular_base/caster/caster_yoke',
#  688: 'table/game_table/ping_pong_table/table_base/irregular_base/caster/caster_stem',
#  689: 'table/game_table/ping_pong_table/table_base/irregular_base/caster/caster_mounting_plate',
#  690: 'table/game_table/ping_pong_table/table_base/irregular_base/caster/wheel',
#  691: 'table/game_table/ping_pong_table/table_base/irregular_base/caster/brake',
#  692: 'table/game_table/ping_pong_table/table_base/irregular_base/shelf',
#  693: 'table/game_table/ping_pong_table/table_base/irregular_base/bar_stretcher',
#  694: 'table/game_table/ping_pong_table/table_base/irregular_base/circular_stretcher',
#  695: 'table/game_table/ping_pong_table/table_base/irregular_base/runner',
#  696: 'table/game_table/ping_pong_table/table_base/irregular_base/tabletop_connector',
#  697: 'table/game_table/ping_pong_table/ping_pong_net',
#  698: 'table/game_table/ping_pong_table/ping_pong_paddle',
#  699: 'table/game_table/card_table',
#  700: 'table/game_table/card_table/tabletop',
#  701: 'table/game_table/card_table/tabletop/tabletop_surface',
#  702: 'table/game_table/card_table/tabletop/tabletop_surface/bar',
#  703: 'table/game_table/card_table/tabletop/tabletop_surface/board',
#  704: 'table/game_table/card_table/tabletop/tabletop_surface/circle',
#  705: 'table/game_table/card_table/tabletop/tabletop_surface/glass',
#  706: 'table/game_table/card_table/tabletop/tabletop_frame',
#  707: 'table/game_table/card_table/tabletop/tabletop_frame/bar',
#  708: 'table/game_table/card_table/tabletop/tabletop_frame/board',
#  709: 'table/game_table/card_table/tabletop/tabletop_frame/circle',
#  710: 'table/game_table/card_table/tabletop/tabletop_dropleaf',
#  711: 'table/game_table/card_table/tabletop/tabletop_dropleaf/bar',
#  712: 'table/game_table/card_table/tabletop/tabletop_dropleaf/board',
#  713: 'table/game_table/card_table/tabletop/tabletop_dropleaf/circle',
#  714: 'table/game_table/card_table/tabletop/tabletop_dropleaf/glass',
#  715: 'table/game_table/card_table/table_base',
#  716: 'table/game_table/card_table/table_base/regular_leg_base',
#  717: 'table/game_table/card_table/table_base/regular_leg_base/leg',
#  718: 'table/game_table/card_table/table_base/regular_leg_base/foot',
#  719: 'table/game_table/card_table/table_base/regular_leg_base/caster',
#  720: 'table/game_table/card_table/table_base/regular_leg_base/caster/caster_yoke',
#  721: 'table/game_table/card_table/table_base/regular_leg_base/caster/caster_stem',
#  722: 'table/game_table/card_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  723: 'table/game_table/card_table/table_base/regular_leg_base/caster/wheel',
#  724: 'table/game_table/card_table/table_base/regular_leg_base/caster/brake',
#  725: 'table/game_table/card_table/table_base/regular_leg_base/bar_stretcher',
#  726: 'table/game_table/card_table/table_base/regular_leg_base/circular_stretcher',
#  727: 'table/game_table/card_table/table_base/regular_leg_base/runner',
#  728: 'table/game_table/card_table/table_base/regular_leg_base/tabletop_connector',
#  729: 'table/game_table/card_table/table_base/star_leg_base',
#  730: 'table/game_table/card_table/table_base/star_leg_base/central_support',
#  731: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set',
#  732: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/leg',
#  733: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/foot',
#  734: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster',
#  735: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  736: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  737: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  738: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  739: 'table/game_table/card_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  740: 'table/game_table/card_table/table_base/star_leg_base/tabletop_connector',
#  741: 'table/game_table/card_table/table_base/pedestal_base',
#  742: 'table/game_table/card_table/table_base/pedestal_base/central_support',
#  743: 'table/game_table/card_table/table_base/pedestal_base/pedestal',
# ...
#  800: 'table/game_table/card_table/table_base/drawer_base/caster/caster_mounting_plate',
#  801: 'table/game_table/card_table/table_base/drawer_base/caster/wheel',
#  802: 'table/game_table/card_table/table_base/drawer_base/caster/brake',
#  803: 'table/game_table/card_table/table_base/drawer_base/runner',
#  804: 'table/game_table/card_table/table_base/drawer_base/bar_stretcher',
#  805: 'table/game_table/card_table/table_base/drawer_base/circular_stretcher',
#  806: 'table/game_table/card_table/table_base/drawer_base/tabletop_connector',
#  807: 'table/game_table/card_table/table_base/irregular_base',
#  808: 'table/game_table/card_table/table_base/irregular_base/leg',
#  809: 'table/game_table/card_table/table_base/irregular_base/foot',
#  810: 'table/game_table/card_table/table_base/irregular_base/caster',
#  811: 'table/game_table/card_table/table_base/irregular_base/caster/caster_yoke',
#  812: 'table/game_table/card_table/table_base/irregular_base/caster/caster_stem',
#  813: 'table/game_table/card_table/table_base/irregular_base/caster/caster_mounting_plate',
#  814: 'table/game_table/card_table/table_base/irregular_base/caster/wheel',
#  815: 'table/game_table/card_table/table_base/irregular_base/caster/brake',
#  816: 'table/game_table/card_table/table_base/irregular_base/shelf',
#  817: 'table/game_table/card_table/table_base/irregular_base/bar_stretcher',
#  818: 'table/game_table/card_table/table_base/irregular_base/circular_stretcher',
#  819: 'table/game_table/card_table/table_base/irregular_base/runner',
#  820: 'table/game_table/card_table/table_base/irregular_base/tabletop_connector',
#  821: 'table/game_table/foosball_table',
#  822: 'table/game_table/foosball_table/tabletop',
#  823: 'table/game_table/foosball_table/tabletop/tabletop_surface',
#  824: 'table/game_table/foosball_table/tabletop/tabletop_surface/bar',
#  825: 'table/game_table/foosball_table/tabletop/tabletop_surface/board',
#  826: 'table/game_table/foosball_table/tabletop/tabletop_surface/circle',
#  827: 'table/game_table/foosball_table/tabletop/tabletop_surface/glass',
#  828: 'table/game_table/foosball_table/tabletop/tabletop_frame',
#  829: 'table/game_table/foosball_table/tabletop/tabletop_frame/bar',
#  830: 'table/game_table/foosball_table/tabletop/tabletop_frame/board',
#  831: 'table/game_table/foosball_table/tabletop/tabletop_frame/circle',
#  832: 'table/game_table/foosball_table/tabletop/tabletop_dropleaf',
#  833: 'table/game_table/foosball_table/tabletop/tabletop_dropleaf/bar',
#  834: 'table/game_table/foosball_table/tabletop/tabletop_dropleaf/board',
#  835: 'table/game_table/foosball_table/tabletop/tabletop_dropleaf/circle',
#  836: 'table/game_table/foosball_table/tabletop/tabletop_dropleaf/glass',
#  837: 'table/game_table/foosball_table/table_base',
#  838: 'table/game_table/foosball_table/table_base/regular_leg_base',
#  839: 'table/game_table/foosball_table/table_base/regular_leg_base/leg',
#  840: 'table/game_table/foosball_table/table_base/regular_leg_base/foot',
#  841: 'table/game_table/foosball_table/table_base/regular_leg_base/caster',
#  842: 'table/game_table/foosball_table/table_base/regular_leg_base/caster/caster_yoke',
#  843: 'table/game_table/foosball_table/table_base/regular_leg_base/caster/caster_stem',
#  844: 'table/game_table/foosball_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  845: 'table/game_table/foosball_table/table_base/regular_leg_base/caster/wheel',
#  846: 'table/game_table/foosball_table/table_base/regular_leg_base/caster/brake',
#  847: 'table/game_table/foosball_table/table_base/regular_leg_base/bar_stretcher',
#  848: 'table/game_table/foosball_table/table_base/regular_leg_base/circular_stretcher',
#  849: 'table/game_table/foosball_table/table_base/regular_leg_base/runner',
#  850: 'table/game_table/foosball_table/table_base/regular_leg_base/tabletop_connector',
#  851: 'table/game_table/foosball_table/table_base/star_leg_base',
#  852: 'table/game_table/foosball_table/table_base/star_leg_base/central_support',
#  853: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set',
#  854: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/leg',
#  855: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/foot',
#  856: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster',
#  857: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  858: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  859: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  860: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  861: 'table/game_table/foosball_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  862: 'table/game_table/foosball_table/table_base/star_leg_base/tabletop_connector',
#  863: 'table/game_table/foosball_table/table_base/pedestal_base',
#  864: 'table/game_table/foosball_table/table_base/pedestal_base/central_support',
#  865: 'table/game_table/foosball_table/table_base/pedestal_base/pedestal',
#  866: 'table/game_table/foosball_table/table_base/pedestal_base/tabletop_connector',
#  867: 'table/game_table/foosball_table/table_base/shelving_base',
#  868: 'table/game_table/foosball_table/table_base/shelving_base/shelf',
#  869: 'table/game_table/foosball_table/table_base/shelving_base/keyboard_tray',
#  870: 'table/game_table/foosball_table/table_base/shelving_base/keyboard_tray/keyboard_tray_surface',
#  871: 'table/game_table/foosball_table/table_base/shelving_base/keyboard_tray/keyboard_tray_rails',
#  872: 'table/game_table/foosball_table/table_base/shelving_base/keyboard_tray/keyboard_tray_slider',
#  873: 'table/game_table/foosball_table/table_base/shelving_base/back_panel',
#  874: 'table/game_table/foosball_table/table_base/shelving_base/vertical_side_panel',
#  875: 'table/game_table/foosball_table/table_base/shelving_base/vertical_front_panel',
#  876: 'table/game_table/foosball_table/table_base/shelving_base/vertical_divider_panel',
#  877: 'table/game_table/foosball_table/table_base/shelving_base/base_side_panel',
#  878: 'table/game_table/foosball_table/table_base/shelving_base/bottom_panel',
#  879: 'table/game_table/foosball_table/table_base/shelving_base/leg',
#  880: 'table/game_table/foosball_table/table_base/shelving_base/foot',
#  881: 'table/game_table/foosball_table/table_base/shelving_base/caster',
#  882: 'table/game_table/foosball_table/table_base/shelving_base/caster/caster_yoke',
#  883: 'table/game_table/foosball_table/table_base/shelving_base/caster/caster_stem',
#  884: 'table/game_table/foosball_table/table_base/shelving_base/caster/caster_mounting_plate',
#  885: 'table/game_table/foosball_table/table_base/shelving_base/caster/wheel',
#  886: 'table/game_table/foosball_table/table_base/shelving_base/caster/brake',
#  887: 'table/game_table/foosball_table/table_base/shelving_base/runner',
#  888: 'table/game_table/foosball_table/table_base/shelving_base/bar_stretcher',
#  889: 'table/game_table/foosball_table/table_base/shelving_base/circular_stretcher',
#  890: 'table/game_table/foosball_table/table_base/shelving_base/tabletop_connector',
#  891: 'table/game_table/foosball_table/table_base/drawer_base',
#  892: 'table/game_table/foosball_table/table_base/drawer_base/drawer',
#  893: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_box',
#  894: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_box/drawer_front',
#  895: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_box/drawer_side',
#  896: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_box/drawer_back',
#  897: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_box/drawer_bottom',
#  898: 'table/game_table/foosball_table/table_base/drawer_base/drawer/handle',
#  899: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_rails',
#  900: 'table/game_table/foosball_table/table_base/drawer_base/drawer/drawer_slider',
#  901: 'table/game_table/foosball_table/table_base/drawer_base/cabinet_door',
#  902: 'table/game_table/foosball_table/table_base/drawer_base/cabinet_door/cabinet_door_surface',
#  903: 'table/game_table/foosball_table/table_base/drawer_base/cabinet_door/handle',
#  904: 'table/game_table/foosball_table/table_base/drawer_base/cabinet_door/hinge',
#  905: 'table/game_table/foosball_table/table_base/drawer_base/cabinet_door/glass',
#  906: 'table/game_table/foosball_table/table_base/drawer_base/shelf',
#  907: 'table/game_table/foosball_table/table_base/drawer_base/keyboard_tray',
#  908: 'table/game_table/foosball_table/table_base/drawer_base/keyboard_tray/keyboard_tray_surface',
#  909: 'table/game_table/foosball_table/table_base/drawer_base/keyboard_tray/keyboard_tray_rails',
#  910: 'table/game_table/foosball_table/table_base/drawer_base/keyboard_tray/keyboard_tray_slider',
#  911: 'table/game_table/foosball_table/table_base/drawer_base/back_panel',
#  912: 'table/game_table/foosball_table/table_base/drawer_base/vertical_side_panel',
#  913: 'table/game_table/foosball_table/table_base/drawer_base/vertical_front_panel',
#  914: 'table/game_table/foosball_table/table_base/drawer_base/vertical_divider_panel',
#  915: 'table/game_table/foosball_table/table_base/drawer_base/base_side_panel',
#  916: 'table/game_table/foosball_table/table_base/drawer_base/bottom_panel',
#  917: 'table/game_table/foosball_table/table_base/drawer_base/leg',
#  918: 'table/game_table/foosball_table/table_base/drawer_base/foot',
#  919: 'table/game_table/foosball_table/table_base/drawer_base/caster',
#  920: 'table/game_table/foosball_table/table_base/drawer_base/caster/caster_yoke',
#  921: 'table/game_table/foosball_table/table_base/drawer_base/caster/caster_stem',
#  922: 'table/game_table/foosball_table/table_base/drawer_base/caster/caster_mounting_plate',
#  923: 'table/game_table/foosball_table/table_base/drawer_base/caster/wheel',
#  924: 'table/game_table/foosball_table/table_base/drawer_base/caster/brake',
#  925: 'table/game_table/foosball_table/table_base/drawer_base/runner',
#  926: 'table/game_table/foosball_table/table_base/drawer_base/bar_stretcher',
#  927: 'table/game_table/foosball_table/table_base/drawer_base/circular_stretcher',
#  928: 'table/game_table/foosball_table/table_base/drawer_base/tabletop_connector',
#  929: 'table/game_table/foosball_table/table_base/irregular_base',
#  930: 'table/game_table/foosball_table/table_base/irregular_base/leg',
#  931: 'table/game_table/foosball_table/table_base/irregular_base/foot',
#  932: 'table/game_table/foosball_table/table_base/irregular_base/caster',
#  933: 'table/game_table/foosball_table/table_base/irregular_base/caster/caster_yoke',
#  934: 'table/game_table/foosball_table/table_base/irregular_base/caster/caster_stem',
#  935: 'table/game_table/foosball_table/table_base/irregular_base/caster/caster_mounting_plate',
#  936: 'table/game_table/foosball_table/table_base/irregular_base/caster/wheel',
#  937: 'table/game_table/foosball_table/table_base/irregular_base/caster/brake',
#  938: 'table/game_table/foosball_table/table_base/irregular_base/shelf',
#  939: 'table/game_table/foosball_table/table_base/irregular_base/bar_stretcher',
#  940: 'table/game_table/foosball_table/table_base/irregular_base/circular_stretcher',
#  941: 'table/game_table/foosball_table/table_base/irregular_base/runner',
#  942: 'table/game_table/foosball_table/table_base/irregular_base/tabletop_connector',
#  943: 'table/game_table/foosball_table/foosball_rod',
#  944: 'table/game_table/foosball_table/foosball_handle',
#  945: 'table/game_table/foosball_table/foosball_player',
#  946: 'table/game_table/airhockey_table',
#  947: 'table/game_table/airhockey_table/tabletop',
#  948: 'table/game_table/airhockey_table/tabletop/tabletop_surface',
#  949: 'table/game_table/airhockey_table/tabletop/tabletop_surface/bar',
#  950: 'table/game_table/airhockey_table/tabletop/tabletop_surface/board',
#  951: 'table/game_table/airhockey_table/tabletop/tabletop_surface/circle',
#  952: 'table/game_table/airhockey_table/tabletop/tabletop_surface/glass',
#  953: 'table/game_table/airhockey_table/tabletop/tabletop_frame',
#  954: 'table/game_table/airhockey_table/tabletop/tabletop_frame/bar',
#  955: 'table/game_table/airhockey_table/tabletop/tabletop_frame/board',
#  956: 'table/game_table/airhockey_table/tabletop/tabletop_frame/circle',
#  957: 'table/game_table/airhockey_table/tabletop/tabletop_dropleaf',
#  958: 'table/game_table/airhockey_table/tabletop/tabletop_dropleaf/bar',
#  959: 'table/game_table/airhockey_table/tabletop/tabletop_dropleaf/board',
#  960: 'table/game_table/airhockey_table/tabletop/tabletop_dropleaf/circle',
#  961: 'table/game_table/airhockey_table/tabletop/tabletop_dropleaf/glass',
#  962: 'table/game_table/airhockey_table/table_base',
#  963: 'table/game_table/airhockey_table/table_base/regular_leg_base',
#  964: 'table/game_table/airhockey_table/table_base/regular_leg_base/leg',
#  965: 'table/game_table/airhockey_table/table_base/regular_leg_base/foot',
#  966: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster',
#  967: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster/caster_yoke',
#  968: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster/caster_stem',
#  969: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster/caster_mounting_plate',
#  970: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster/wheel',
#  971: 'table/game_table/airhockey_table/table_base/regular_leg_base/caster/brake',
#  972: 'table/game_table/airhockey_table/table_base/regular_leg_base/bar_stretcher',
#  973: 'table/game_table/airhockey_table/table_base/regular_leg_base/circular_stretcher',
#  974: 'table/game_table/airhockey_table/table_base/regular_leg_base/runner',
#  975: 'table/game_table/airhockey_table/table_base/regular_leg_base/tabletop_connector',
#  976: 'table/game_table/airhockey_table/table_base/star_leg_base',
#  977: 'table/game_table/airhockey_table/table_base/star_leg_base/central_support',
#  978: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set',
#  979: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/leg',
#  980: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/foot',
#  981: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster',
#  982: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster/caster_yoke',
#  983: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster/caster_stem',
#  984: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster/caster_mounting_plate',
#  985: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster/wheel',
#  986: 'table/game_table/airhockey_table/table_base/star_leg_base/star_leg_set/caster/brake',
#  987: 'table/game_table/airhockey_table/table_base/star_leg_base/tabletop_connector',
#  988: 'table/game_table/airhockey_table/table_base/pedestal_base',
#  989: 'table/game_table/airhockey_table/table_base/pedestal_base/central_support',
#  990: 'table/game_table/airhockey_table/table_base/pedestal_base/pedestal',
#  991: 'table/game_table/airhockey_table/table_base/pedestal_base/tabletop_connector',
#  992: 'table/game_table/airhockey_table/table_base/shelving_base',
#  993: 'table/game_table/airhockey_table/table_base/shelving_base/shelf',
#  994: 'table/game_table/airhockey_table/table_base/shelving_base/keyboard_tray',
#  995: 'table/game_table/airhockey_table/table_base/shelving_base/keyboard_tray/keyboard_tray_surface',
#  996: 'table/game_table/airhockey_table/table_base/shelving_base/keyboard_tray/keyboard_tray_rails',
#  997: 'table/game_table/airhockey_table/table_base/shelving_base/keyboard_tray/keyboard_tray_slider',
#  998: 'table/game_table/airhockey_table/table_base/shelving_base/back_panel',
#  999: 'table/game_table/airhockey_table/table_base/shelving_base/vertical_side_panel',
#  1000: 'table/game_table/airhockey_table/table_base/shelving_base/vertical_front_panel',
#  ...}
